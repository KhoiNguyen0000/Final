# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('Datasets/Clean_data/Locality_Analyst.csv')

# %%
Data.head()
# Out:
#      Vùng   Năm  Diện tích(Km2)  Dân số trung bình (Nghìn người)  \
# 0  Hà Nội  2011          3328.9                           6825.8
# 1  Hà Nội  2012          3323.6                           6991.4
# 2  Hà Nội  2013          3324.3                           7128.4
# 3  Hà Nội  2014          3324.5                           7285.5
# 4  Hà Nội  2015          3324.5                           7433.6
#
#    Mật độ dân số (Người/km2)  Tổng dân số      Nam       Nữ  \
# 0                     2050.5      6825.82  3359.81  3466.00
# 1                     2103.6      6991.43  3444.43  3547.01
# 2                     2144.3      7128.39  3515.06  3613.33
# 3                     2191.5      7285.53  3595.78  3689.76
# 4                     2236.0      7433.60  3672.20  3761.40
#
#    Tổng dân số thành thị  Tổng dân số nông thôn  ...  Tỷ suất chết thô  \
# 0                2900.37                3925.45  ...               6.8
# 1                2972.61                4018.82  ...               7.2
# 2                3024.64                4103.75  ...               7.3
# 3                3583.51                3702.03  ...               6.6
# 4                3650.50                3783.10  ...               7.3
#
#    Tỷ lệ tăng tự nhiên  Tỷ suất nhập cư  Tỷ suất xuất cư  Tỷ suất di cư thuần  \
# 0                 11.8             11.0              6.4                  4.7
# 1                  9.9              6.1              3.3                  2.8
# 2                  9.2              7.7              7.4                  0.3
# 3                 12.3              7.5              7.8                 -0.4
# 4                  9.1              4.7              4.1                  0.6
#
#    Tỷ lệ nam nữ              Khu vực Tỉ lệ thất nghiệp  \
# 0         96.94  Đồng bằng sông Hồng              3.35
# 1         97.11  Đồng bằng sông Hồng              1.19
# 2         97.28  Đồng bằng sông Hồng              1.92
# 3         97.45  Đồng bằng sông Hồng              1.60
# 4         97.60  Đồng bằng sông Hồng              4.13
#
#    Tỉ lệ thất nghiệp ở thành thị  Tỉ lệ thất nghiệp ở nông thôn
# 0                           2.82                           1.48
# 1                           1.34                           5.59
# 2                           0.89                           5.15
# 3                           2.07                           4.65
# 4                           3.77                           3.63
#
# [5 rows x 21 columns]

# %%
Data['Tỷ lệ dân số thành thị(%)'] = round(Data['Tổng dân số thành thị'] / Data['Tổng dân số'] * 100, 2)
Data['Tỷ lệ dân số nông thôn(%)'] = round(Data['Tổng dân số nông thôn'] / Data['Tổng dân số'] * 100, 2)

# %%
Data_mean = round(Data.groupby('Vùng', as_index=False).mean(numeric_only=True), 2)
Data_mean = Data_mean.drop(columns='Năm')
Data_mean
# Out:
#                  Vùng  Diện tích(Km2)  Dân số trung bình (Nghìn người)  \
# 0            An Giang         3536.74                          1968.56
# 1   Bà Rịa - Vũng Tàu         1984.59                          1129.52
# 2          Bình Dương         2694.54                          2300.86
# 3          Bình Phước         6873.75                           979.43
# 4          Bình Thuận         7896.66                          1223.15
# ..                ...             ...                              ...
# 58            Ðà Nẵng         1284.99                          1115.18
# 59            Ðắk Lắk        13078.64                          1855.07
# 60           Ðắk Nông         6511.55                           609.05
# 61           Ðồng Nai         5879.17                          3019.80
# 62          Ðồng Tháp         3381.24                          1616.84
#
#     Mật độ dân số (Người/km2)  Tổng dân số      Nam       Nữ  \
# 0                      556.58      1968.57   977.60   990.97
# 1                      569.23      1129.52   564.47   565.06
# 2                      853.94      2300.87  1155.66  1145.20
# 3                      142.49       979.42   494.53   484.89
# 4                      154.90      1223.14   614.60   608.53
# ..                        ...          ...      ...      ...
# 58                     867.89      1115.18   550.76   564.42
# 59                     141.86      1855.07   936.25   918.83
# 60                      93.51       609.04   313.62   295.42
# 61                     513.71      3019.80  1511.91  1507.89
# 62                     478.10      1616.85   807.59   809.25
#
#     Tổng dân số thành thị  Tổng dân số nông thôn  Tỷ suất sinh thô  ...  \
# 0                  625.98                1342.59             13.16  ...
# 1                  642.36                 487.17             13.68  ...
# 2                 1804.90                 495.98             18.41  ...
# 3                  228.47                 750.93             17.13  ...
# 4                  471.34                 751.80             14.84  ...
# ..                    ...                    ...               ...  ...
# 58                 972.71                 142.46             17.59  ...
# 59                 459.43                1395.65             17.29  ...
# 60                  95.23                 513.81             18.64  ...
# 61                1160.79                1859.00             15.98  ...
# 62                 304.14                1312.72             12.14  ...
#
#     Tỷ lệ tăng tự nhiên  Tỷ suất nhập cư  Tỷ suất xuất cư  \
# 0                  4.59             2.34            12.96
# 1                  8.42             7.32             5.63
# 2                 14.12            45.78             9.30
# 3                 11.40             5.39             6.32
# 4                  8.78             1.56             5.75
# ..                  ...              ...              ...
# 58                11.78            14.41             5.74
# 59                11.72             3.53             6.57
# 60                13.52            10.02             6.79
# 61                10.55            13.65             5.77
# 62                 4.94             2.56            10.04
#
#     Tỷ suất di cư thuần  Tỷ lệ nam nữ  Tỉ lệ thất nghiệp  \
# 0                -10.63         98.77               2.82
# 1                  1.70         99.91               3.15
# 2                 36.48         99.99               2.63
# 3                 -0.93        101.74               2.59
# 4                 -4.18        100.84               2.66
# ..                  ...           ...                ...
# 58                 8.68         97.48               3.23
# 59                -3.04        101.88               2.76
# 60                 3.22        106.12               2.42
# 61                 7.86        100.36               3.29
# 62                -7.49         99.96               2.79
#
#     Tỉ lệ thất nghiệp ở thành thị  Tỉ lệ thất nghiệp ở nông thôn  \
# 0                            2.16                           3.58
# 1                            1.80                           3.19
# 2                            2.11                           3.01
# 3                            1.70                           3.72
# 4                            2.10                           3.10
# ..                            ...                            ...
# 58                           2.69                           3.29
# 59                           2.48                           3.64
# 60                           2.25                           3.23
# 61                           1.96                           3.24
# 62                           2.12                           3.48
#
#     Tỷ lệ dân số thành thị(%)  Tỷ lệ dân số nông thôn(%)
# 0                       31.86                      68.14
# 1                       56.74                      43.26
# 2                       77.31                      22.69
# 3                       23.14                      76.86
# 4                       38.54                      61.46
# ..                        ...                        ...
# 58                      87.20                      12.79
# 59                      24.75                      75.25
# 60                      15.57                      84.43
# 61                      38.08                      61.92
# 62                      18.82                      81.18
#
# [63 rows x 21 columns]

# %%
year_mean = (Data.drop(columns=['Vùng', 'Khu vực'])).copy()
year_mean = round(Data.groupby('Năm', as_index=False).mean(numeric_only=True), 2)
year_mean
# Out:
#      Năm  Diện tích(Km2)  Dân số trung bình (Nghìn người)  \
# 0   2011         5253.30                          1399.13
# 1   2012         5253.20                          1415.92
# 2   2013         5253.53                          1431.61
# 3   2014         5253.44                          1447.68
# 4   2015         5253.44                          1463.95
# 5   2016         5253.20                          1480.17
# 6   2017         5253.20                          1496.60
# 7   2018         5253.26                          1514.05
# 8   2019         5253.27                          1531.49
# 9   2020         5258.78                          1548.93
# 10  2021         5259.24                          1563.59
# 11  2022         5259.26                          1578.96
# 12  2023         5259.24                          1592.21
# 13  2024         5259.14                          1608.63
#
#     Mật độ dân số (Người/km2)  Tổng dân số     Nam      Nữ  \
# 0                      468.12      1399.14  692.37  706.77
# 1                      474.20      1415.92  701.08  714.84
# 2                      479.61      1431.61  709.30  722.31
# 3                      485.36      1447.68  717.66  730.02
# 4                      491.25      1463.95  726.25  737.70
# 5                      495.88      1480.17  734.84  745.33
# 6                      501.77      1496.60  743.62  752.98
# 7                      508.06      1514.05  752.82  761.24
# 8                      514.44      1531.49  762.19  769.31
# 9                      519.89      1548.93  771.83  777.10
# 10                     524.68      1563.56  779.17  784.39
# 11                     530.49      1578.86  787.06  791.80
# 12                     535.08      1592.21  794.29  797.92
# 13                     540.74      1608.63  802.81  805.82
#
#     Tổng dân số thành thị  Tổng dân số nông thôn  Tỷ suất sinh thô  ...  \
# 0                  439.34                 959.80             17.21  ...
# 1                  448.81                 967.11             17.68  ...
# 2                  458.18                 973.43             17.28  ...
# 3                  480.52                 967.16             17.74  ...
# 4                  490.19                 973.76             16.69  ...
# 5                  498.37                 981.80             16.56  ...
# 6                  506.80                 989.80             15.35  ...
# 7                  518.05                 996.00             14.93  ...
# 8                  536.77                 994.72             16.18  ...
# 9                  569.94                 978.99             16.28  ...
# 10                 580.26                 983.30             15.77  ...
# 11                 592.82                 986.04             15.15  ...
# 12                 606.66                 985.55             14.28  ...
# 13                 619.16                 989.47             13.70  ...
#
#     Tỷ lệ tăng tự nhiên  Tỷ suất nhập cư  Tỷ suất xuất cư  \
# 0                 10.22             8.20             9.90
# 1                 10.58             6.50             7.12
# 2                 10.06             7.67             8.36
# 3                 10.77             7.73             8.80
# 4                  9.72             4.22             5.43
# 5                  9.69             3.38             4.78
# 6                  8.26             2.76             3.66
# 7                  7.79             3.09             4.36
# 8                  9.60             4.26             7.04
# 9                  9.95             4.76             8.24
# 10                 9.30             4.47             7.95
# 11                 8.13             3.70             5.29
# 12                 8.46             3.62             5.52
# 13                 7.46             5.11             6.85
#
#     Tỷ suất di cư thuần  Tỷ lệ nam nữ  Tỉ lệ thất nghiệp  \
# 0                 -1.70         98.94               2.93
# 1                 -0.63         99.03               3.32
# 2                 -0.68         99.14               3.00
# 3                 -1.06         99.21               3.03
# 4                 -1.21         99.32               3.14
# 5                 -1.40         99.44               2.90
# 6                 -0.90         99.58               2.66
# 7                 -1.28         99.68               2.78
# 8                 -2.77         99.83               3.06
# 9                 -3.48         99.93               2.82
# 10                -3.48         99.92               3.10
# 11                -1.59        100.49               3.17
# 12                -1.90         98.52               2.56
# 13                -1.74        100.41               3.05
#
#     Tỉ lệ thất nghiệp ở thành thị  Tỉ lệ thất nghiệp ở nông thôn  \
# 0                            2.16                           3.27
# 1                            2.08                           3.18
# 2                            2.32                           3.45
# 3                            2.37                           3.23
# 4                            2.23                           3.31
# 5                            2.28                           3.35
# 6                            2.22                           3.36
# 7                            2.08                           3.26
# 8                            2.26                           3.52
# 9                            2.20                           3.16
# 10                           2.04                           3.17
# 11                           2.37                           3.23
# 12                           2.36                           3.27
# 13                           2.43                           3.56
#
#     Tỷ lệ dân số thành thị(%)  Tỷ lệ dân số nông thôn(%)
# 0                       26.25                      73.75
# 1                       26.48                      73.52
# 2                       26.76                      73.24
# 3                       27.47                      72.53
# 4                       27.71                      72.29
# 5                       27.85                      72.15
# 6                       28.01                      71.99
# 7                       28.27                      71.73
# 8                       28.86                      71.14
# 9                       30.71                      69.29
# 10                      31.08                      68.92
# 11                      31.51                      68.49
# 12                      32.07                      67.93
# 13                      32.44                      67.56
#
# [14 rows x 21 columns]

# %%
Data.describe()
# Out:
#                Năm  Diện tích(Km2)  Dân số trung bình (Nghìn người)  \
# count   882.000000      882.000000                       882.000000
# mean   2017.500000     5255.391497                      1505.208844
# std       4.033416     3650.396201                      1378.415102
# min    2011.000000      822.700000                       298.700000
# 25%    2014.000000     2359.575000                       868.650000
# 50%    2017.500000     4701.200000                      1208.050000
# 75%    2021.000000     6871.500000                      1631.950000
# max    2024.000000    16493.700000                      9543.600000
#
#        Mật độ dân số (Người/km2)  Tổng dân số          Nam           Nữ  \
# count                 882.000000   882.000000   882.000000   882.000000
# mean                  504.970408  1505.200283   748.233560   756.967075
# std                   641.699527  1378.416837   675.791816   702.834180
# min                    43.300000   298.690000   150.920000   147.770000
# 25%                   137.000000   868.650000   434.877500   433.395000
# 50%                   269.800000  1208.065000   605.200000   605.300000
# 75%                   667.800000  1631.940000   814.090000   817.422500
# max                  4554.600000  9543.630000  4626.650000  4916.980000
#
#        Tổng dân số thành thị  Tổng dân số nông thôn  Tỷ suất sinh thô  ...  \
# count             882.000000             882.000000        882.000000  ...
# mean              524.704909             980.495510         16.057120  ...
# std               970.664130             651.718657          3.160254  ...
# min                50.550000             126.710000          9.500000  ...
# 25%               174.797500             589.392500         13.700000  ...
# 50%               266.650000             810.245000         15.970000  ...
# 75%               483.227500            1167.437500         18.100000  ...
# max              7428.600000            4436.790000         27.200000  ...
#
#        Tỷ lệ tăng tự nhiên  Tỷ suất nhập cư  Tỷ suất xuất cư  \
# count           882.000000       882.000000       882.000000
# mean              9.284773         4.962109         6.665102
# std               3.503375         7.479989         3.843865
# min              -0.940000         0.100000         0.800000
# 25%               7.000000         1.500000         3.862500
# 50%               9.130000         2.900000         6.080000
# 75%              11.600000         5.200000         8.452500
# max              19.800000        70.200000        25.790000
#
#        Tỷ suất di cư thuần  Tỷ lệ nam nữ  Tỉ lệ thất nghiệp  \
# count           882.000000    882.000000         882.000000
# mean             -1.702381     99.530737           2.964195
# std               7.993909      2.562378           1.384071
# min             -23.760000     90.520000           0.470000
# 25%              -5.000000     97.702500           1.740000
# 50%              -2.365000     99.515000           3.020000
# 75%              -0.202500    101.350000           4.210000
# max              58.600000    108.080000           5.250000
#
#        Tỉ lệ thất nghiệp ở thành thị  Tỉ lệ thất nghiệp ở nông thôn  \
# count                     882.000000                     882.000000
# mean                        2.244229                       3.307177
# std                         1.141735                       1.514091
# min                         0.310000                       0.640000
# 25%                         1.215000                       2.010000
# 50%                         2.285000                       3.325000
# 75%                         3.170000                       4.570000
# max                         4.270000                       6.010000
#
#        Tỷ lệ dân số thành thị(%)  Tỷ lệ dân số nông thôn(%)
# count                 882.000000                 882.000000
# mean                   28.962086                  71.037857
# std                    17.197121                  17.197272
# min                     9.760000                  12.190000
# 25%                    16.912500                  67.140000
# 50%                    23.335000                  76.665000
# 75%                    32.860000                  83.087500
# max                    87.810000                  90.240000
#
# [8 rows x 21 columns]

# %%
Data.columns
# Out:
# Index(['Vùng', 'Năm', 'Diện tích(Km2)', 'Dân số trung bình (Nghìn người)',
#        'Mật độ dân số (Người/km2)', 'Tổng dân số', 'Nam', 'Nữ',
#        'Tổng dân số thành thị', 'Tổng dân số nông thôn', 'Tỷ suất sinh thô',
#        'Tỷ suất chết thô', 'Tỷ lệ tăng tự nhiên', 'Tỷ suất nhập cư',
#        'Tỷ suất xuất cư', 'Tỷ suất di cư thuần', 'Tỷ lệ nam nữ', 'Khu vực',
#        'Tỉ lệ thất nghiệp', 'Tỉ lệ thất nghiệp ở thành thị',
#        'Tỉ lệ thất nghiệp ở nông thôn', 'Tỷ lệ dân số thành thị(%)',
#        'Tỷ lệ dân số nông thôn(%)'],
#       dtype='object')

# %%
def visual_scatter(var: str):
    label = 'Tổng dân số'
    plt.scatter(Data[var],Data[label] , alpha=0.3)
    plt.xlabel(var)
    plt.ylabel(label)

# %%
visual_scatter('Tổng dân số thành thị')

# %%
visual_scatter('Tổng dân số nông thôn')

# %%
visual_scatter('Tỷ suất sinh thô')

# %%
visual_scatter('Tỷ suất chết thô')

# %%
visual_scatter('Tỷ suất nhập cư')

# %%
visual_scatter('Tỷ suất xuất cư')

# %%
visual_scatter('Tỷ suất di cư thuần')

# %%
def column_chart_vertical(temp: str):
    df = Data_mean.sort_values('Vùng').copy()
    x = df['Vùng']
    y = pd.to_numeric(df[temp], errors="coerce")

    plt.figure(figsize=(8,12))
    plt.barh(x, y, height=0.6)                      
    plt.xlabel(temp); plt.ylabel('Vùng')
    plt.title(f"{temp} theo {'Vùng'}")
    plt.grid(axis="x")
    plt.margins(y = 0.01)
    plt.tight_layout(); plt.show()

# %%
column_chart_vertical('Tổng dân số')

# %%
column_chart_vertical('Mật độ dân số (Người/km2)')

# %%
column_chart_vertical('Tỷ suất di cư thuần')

# %%
def double_column_chart_vertical(var, temp: str):
    df = Data_mean.sort_values('Vùng').copy()
    x_labels = df['Vùng']
    y_var = pd.to_numeric(df[var], errors="coerce")
    y_temp = pd.to_numeric(df[temp], errors='coerce')

    plt.figure(figsize=(8,20))
    x = np.arange(len(x_labels))
    height=0.4
    plt.barh(x - height/2,y_var, height=height, color='#4A90E2', label=var)
    plt.barh(x + height/2,y_temp, height=height, color='#E67E22', label=temp)

    plt.yticks(ticks=x, labels=x_labels)
    plt.xlabel('Vùng'); plt.ylabel('Giá trị tổng quát')
    plt.title(f'Giá trị {var} và {temp} theo từng tỉnh')
    plt.grid(axis='x')
    plt.legend()
    plt.margins(y=0.035)
    plt.tight_layout()
    plt.show()

# %%
double_column_chart_vertical('Tỷ lệ dân số thành thị(%)','Tỷ lệ dân số nông thôn(%)')

# %%
double_column_chart_vertical('Tỉ lệ thất nghiệp ở thành thị', 'Tỉ lệ thất nghiệp ở nông thôn')

# %%
def double_column_chart(var, temp: str):
    df = year_mean.sort_values('Năm').copy()
    x = pd.to_numeric(df['Năm'], errors="coerce")
    y_var = pd.to_numeric(df[var], errors="coerce")
    y_temp = pd.to_numeric(df[temp], errors='coerce')

    plt.figure(figsize=(20,8))
    width=0.4
    plt.bar(x - width/2,y_var, width=width, color='#4A90E2', label=var)
    plt.bar(x + width/2,y_temp, width=width, color='#E67E22', label=temp)

    plt.xlabel('Năm'); plt.ylabel('Giá trị tổng quát')
    plt.title(f'Giá trị {var} và {temp} theo năm')
    plt.grid(axis='y')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
double_column_chart('Tỷ lệ dân số thành thị(%)','Tỷ lệ dân số nông thôn(%)')

# %%
double_column_chart('Tỷ suất sinh thô', 'Tỷ suất chết thô')

# %%
double_column_chart('Tỷ suất nhập cư', 'Tỷ suất xuất cư')

# %%
def column_chart_horizontal(temp: str):
    df = year_mean.sort_values('Năm').copy()
    x = pd.to_numeric(df['Năm'], errors="coerce")
    y = pd.to_numeric(df[temp], errors="coerce")

    plt.figure(figsize=(12,6))
    plt.bar(x, y)
    plt.xlabel('Năm'); plt.ylabel(temp)
    plt.title(f"{temp} theo {'Năm'}")
    plt.grid(axis="y")
    plt.tight_layout()
    plt.show()

# %%
column_chart_horizontal('Tỉ lệ thất nghiệp')

# %%
column_chart_horizontal('Dân số trung bình (Nghìn người)')

# %%
column_chart_horizontal('Tỷ lệ tăng tự nhiên')

# %%
def plot_correlation_heatmap(df: pd.core.frame.DataFrame, title_name: str='Train correlation') -> None:

    corr = df.corr()
    fig, axes = plt.subplots(figsize=(12, 8))
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(corr, mask=mask, linewidths=.5, cmap='RdBu_r', annot=True,annot_kws={"size": 8})
    plt.title(title_name)
    plt.show()

# %%
cols = [
        'Tổng dân số',
        'Tổng dân số thành thị',
        'Tổng dân số nông thôn',
        'Tỷ suất sinh thô',
        'Tỷ suất chết thô',
        'Tỷ lệ tăng tự nhiên',
        'Tỷ suất nhập cư',
        'Tỷ suất xuất cư',
        'Tỷ suất di cư thuần',
        'Tỉ lệ thất nghiệp']

plot_correlation_heatmap(Data[cols])
