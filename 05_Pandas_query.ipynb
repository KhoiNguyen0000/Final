# %%
import pandas as pd

# %% [markdown]
# IMPORT DỮ LIỆU

# %%
Locality_data = pd.read_csv('Datasets/Clean_data/Locality_Analyst.csv')

# %%
Locality_data
# Out:
#        Vùng   Năm  Diện tích(Km2)  Dân số trung bình (Nghìn người)  \
# 0    Hà Nội  2011          3328.9                           6825.8
# 1    Hà Nội  2012          3323.6                           6991.4
# 2    Hà Nội  2013          3324.3                           7128.4
# 3    Hà Nội  2014          3324.5                           7285.5
# 4    Hà Nội  2015          3324.5                           7433.6
# ..      ...   ...             ...                              ...
# 877  Cà Mau  2020          5274.5                           1193.9
# 878  Cà Mau  2021          5274.5                           1208.8
# 879  Cà Mau  2022          5274.5                           1207.6
# 880  Cà Mau  2023          5274.5                           1207.4
# 881  Cà Mau  2024          5274.5                           1212.0
#
#      Mật độ dân số (Người/km2)  Tổng dân số      Nam       Nữ  \
# 0                       2050.5      6825.82  3359.81  3466.00
# 1                       2103.6      6991.43  3444.43  3547.01
# 2                       2144.3      7128.39  3515.06  3613.33
# 3                       2191.5      7285.53  3595.78  3689.76
# 4                       2236.0      7433.60  3672.20  3761.40
# ..                         ...          ...      ...      ...
# 877                      226.0      1193.89   604.74   589.16
# 878                      229.0      1208.75   612.26   596.49
# 879                      229.0      1207.63   617.17   590.46
# 880                      228.9      1207.37   617.10   590.28
# 881                      229.8      1212.00   619.50   592.50
#
#      Tổng dân số thành thị  Tổng dân số nông thôn  ...  Tỷ suất chết thô  \
# 0                  2900.37                3925.45  ...              6.80
# 1                  2972.61                4018.82  ...              7.20
# 2                  3024.64                4103.75  ...              7.30
# 3                  3583.51                3702.03  ...              6.60
# 4                  3650.50                3783.10  ...              7.30
# ..                     ...                    ...  ...               ...
# 877                 271.11                 922.78  ...              5.21
# 878                 275.35                 933.40  ...              5.40
# 879                 275.77                 931.86  ...              6.59
# 880                 278.39                 928.99  ...              6.09
# 881                 284.86                 927.14  ...              3.81
#
#      Tỷ lệ tăng tự nhiên  Tỷ suất nhập cư  Tỷ suất xuất cư  \
# 0                  11.80            11.00             6.40
# 1                   9.90             6.10             3.30
# 2                   9.20             7.70             7.40
# 3                  12.30             7.50             7.80
# 4                   9.10             4.70             4.10
# ..                   ...              ...              ...
# 877                 7.95             0.68            15.83
# 878                 7.37             0.82            20.22
# 879                 5.81             0.57            12.89
# 880                 3.73             0.44            11.32
# 881                 8.01             1.38            12.36
#
#      Tỷ suất di cư thuần  Tỷ lệ nam nữ                  Khu vực  \
# 0                   4.70         96.94      Đồng bằng sông Hồng
# 1                   2.80         97.11      Đồng bằng sông Hồng
# 2                   0.30         97.28      Đồng bằng sông Hồng
# 3                  -0.40         97.45      Đồng bằng sông Hồng
# 4                   0.60         97.60      Đồng bằng sông Hồng
# ..                   ...           ...                      ...
# 877               -15.15        102.64  Đồng bằng sông Cửu Long
# 878               -19.39        102.64  Đồng bằng sông Cửu Long
# 879               -12.32        104.52  Đồng bằng sông Cửu Long
# 880               -10.88        100.61  Đồng bằng sông Cửu Long
# 881               -10.97        104.56  Đồng bằng sông Cửu Long
#
#     Tỉ lệ thất nghiệp  Tỉ lệ thất nghiệp ở thành thị  \
# 0                3.35                           2.82
# 1                1.19                           1.34
# 2                1.92                           0.89
# 3                1.60                           2.07
# 4                4.13                           3.77
# ..                ...                            ...
# 877              2.66                           1.23
# 878              3.46                           3.38
# 879              0.73                           3.14
# 880              1.47                           2.41
# 881              5.02                           2.48
#
#      Tỉ lệ thất nghiệp ở nông thôn
# 0                             1.48
# 1                             5.59
# 2                             5.15
# 3                             4.65
# 4                             3.63
# ..                             ...
# 877                           3.57
# 878                           1.33
# 879                           5.41
# 880                           3.74
# 881                           2.43
#
# [882 rows x 21 columns]

# %%
#1. Quan sát xu hướng tăng trưởng dân số theo thời gian.
Locality_data[['Vùng', 'Năm', 'Dân số trung bình (Nghìn người)']].copy()
# Out:
#        Vùng   Năm  Dân số trung bình (Nghìn người)
# 0    Hà Nội  2011                           6825.8
# 1    Hà Nội  2012                           6991.4
# 2    Hà Nội  2013                           7128.4
# 3    Hà Nội  2014                           7285.5
# 4    Hà Nội  2015                           7433.6
# ..      ...   ...                              ...
# 877  Cà Mau  2020                           1193.9
# 878  Cà Mau  2021                           1208.8
# 879  Cà Mau  2022                           1207.6
# 880  Cà Mau  2023                           1207.4
# 881  Cà Mau  2024                           1212.0
#
# [882 rows x 3 columns]

# %%
#2. Tìm vùng có mật độ dân số lớn nhất mỗi năm.
dt2 = Locality_data[['Vùng', 'Năm','Mật độ dân số (Người/km2)']].copy()
idx = dt2.groupby('Năm')['Mật độ dân số (Người/km2)'].idxmax()
dt2_max = dt2.loc[idx]
dt2_max
# Out:
#                Vùng   Năm  Mật độ dân số (Người/km2)
# 686  TP.Hồ Chí Minh  2011                     3633.1
# 687  TP.Hồ Chí Minh  2012                     3717.2
# 688  TP.Hồ Chí Minh  2013                     3805.1
# 689  TP.Hồ Chí Minh  2014                     3882.6
# 690  TP.Hồ Chí Minh  2015                     3964.6
# 691  TP.Hồ Chí Minh  2016                     4113.3
# 692  TP.Hồ Chí Minh  2017                     4196.4
# 693  TP.Hồ Chí Minh  2018                     4289.9
# 694  TP.Hồ Chí Minh  2019                     4385.0
# 695  TP.Hồ Chí Minh  2020                     4404.0
# 696  TP.Hồ Chí Minh  2021                     4375.0
# 697  TP.Hồ Chí Minh  2022                     4481.0
# 698  TP.Hồ Chí Minh  2023                     4513.1
# 699  TP.Hồ Chí Minh  2024                     4554.6

# %%
#3. Xem vùng nào có tốc độ tăng dân số tự nhiên cao/thấp nhất.
Locality_data.groupby('Vùng')['Tỷ lệ tăng tự nhiên'].mean()
# Out:
# Vùng
# An Giang              4.587143
# Bà Rịa - Vũng Tàu     8.415714
# Bình Dương           14.125000
# Bình Phước           11.395714
# Bình Thuận            8.775000
#                        ...
# Ðà Nẵng              11.775000
# Ðắk Lắk              11.715000
# Ðắk Nông             13.515000
# Ðồng Nai             10.545714
# Ðồng Tháp             4.938571
# Name: Tỷ lệ tăng tự nhiên, Length: 63, dtype: float64

# %%
# 4.Kiểm tra sự cân bằng nhân khẩu học
Locality_data['Tỷ suất chết thô'] = Locality_data['Tỷ suất chết thô'] * (-1)
Locality_data[['Tỷ suất sinh thô' ,'Tỷ suất chết thô']].corr(method='pearson')
# Out:
#                   Tỷ suất sinh thô  Tỷ suất chết thô
# Tỷ suất sinh thô          1.000000          0.020731
# Tỷ suất chết thô          0.020731          1.000000

# %%
#5.Đánh giá quá trình đô thị hóa của các vùng.
dt3 = Locality_data[['Vùng', 'Tổng dân số', 'Tổng dân số thành thị', 'Tổng dân số nông thôn']].copy()
dt3 = dt3.groupby('Vùng').mean().round(2)
dt3['Tỷ lệ dân số thành thị(%)'] = round(dt3['Tổng dân số thành thị'] / dt3['Tổng dân số'] * 100, 2)
dt3['Tỷ lệ dân số nông thôn(%)'] = round(dt3['Tổng dân số nông thôn'] / dt3['Tổng dân số'] * 100, 2)
dt3
# Out:
#                    Tổng dân số  Tổng dân số thành thị  Tổng dân số nông thôn  \
# Vùng
# An Giang               1968.57                 625.98                1342.59
# Bà Rịa - Vũng Tàu      1129.52                 642.36                 487.17
# Bình Dương             2300.87                1804.90                 495.98
# Bình Phước              979.42                 228.47                 750.93
# Bình Thuận             1223.14                 471.34                 751.80
# ...                        ...                    ...                    ...
# Ðà Nẵng                1115.18                 972.71                 142.46
# Ðắk Lắk                1855.07                 459.43                1395.65
# Ðắk Nông                609.04                  95.23                 513.81
# Ðồng Nai               3019.80                1160.79                1859.00
# Ðồng Tháp              1616.85                 304.14                1312.72
#
#                    Tỷ lệ dân số thành thị(%)  Tỷ lệ dân số nông thôn(%)
# Vùng
# An Giang                               31.80                      68.20
# Bà Rịa - Vũng Tàu                      56.87                      43.13
# Bình Dương                             78.44                      21.56
# Bình Phước                             23.33                      76.67
# Bình Thuận                             38.54                      61.46
# ...                                      ...                        ...
# Ðà Nẵng                                87.22                      12.77
# Ðắk Lắk                                24.77                      75.23
# Ðắk Nông                               15.64                      84.36
# Ðồng Nai                               38.44                      61.56
# Ðồng Tháp                              18.81                      81.19
#
# [63 rows x 5 columns]

# %%
#6. So sánh thất nghiệp giữa thành thị và nông thôn.
dt4 = Locality_data.copy()
dt4 = dt4.groupby(['Vùng'])[['Tỉ lệ thất nghiệp', 'Tỉ lệ thất nghiệp ở thành thị', 'Tỉ lệ thất nghiệp ở nông thôn']].mean().round(2)
dt4
# Out:
#                    Tỉ lệ thất nghiệp  Tỉ lệ thất nghiệp ở thành thị  \
# Vùng
# An Giang                        2.82                           2.16
# Bà Rịa - Vũng Tàu               3.15                           1.80
# Bình Dương                      2.63                           2.11
# Bình Phước                      2.59                           1.70
# Bình Thuận                      2.66                           2.10
# ...                              ...                            ...
# Ðà Nẵng                         3.23                           2.69
# Ðắk Lắk                         2.76                           2.48
# Ðắk Nông                        2.42                           2.25
# Ðồng Nai                        3.29                           1.96
# Ðồng Tháp                       2.79                           2.12
#
#                    Tỉ lệ thất nghiệp ở nông thôn
# Vùng
# An Giang                                    3.58
# Bà Rịa - Vũng Tàu                           3.19
# Bình Dương                                  3.01
# Bình Phước                                  3.72
# Bình Thuận                                  3.10
# ...                                          ...
# Ðà Nẵng                                     3.29
# Ðắk Lắk                                     3.64
# Ðắk Nông                                    3.23
# Ðồng Nai                                    3.24
# Ðồng Tháp                                   3.48
#
# [63 rows x 3 columns]

# %%
#7. Xem vùng có tăng dân số mạnh có tỷ lệ thất nghiệp cao không.
Locality_data.groupby('Vùng')[['Tỷ lệ tăng tự nhiên','Tỉ lệ thất nghiệp']].mean().round(2)
# Out:
#                    Tỷ lệ tăng tự nhiên  Tỉ lệ thất nghiệp
# Vùng
# An Giang                          4.59               2.82
# Bà Rịa - Vũng Tàu                 8.42               3.15
# Bình Dương                       14.12               2.63
# Bình Phước                       11.40               2.59
# Bình Thuận                        8.78               2.66
# ...                                ...                ...
# Ðà Nẵng                          11.78               3.23
# Ðắk Lắk                          11.72               2.76
# Ðắk Nông                         13.52               2.42
# Ðồng Nai                         10.55               3.29
# Ðồng Tháp                         4.94               2.79
#
# [63 rows x 2 columns]

# %%
#8. Xem vùng nào thu hút hay mất dân cư.
dt5 = Locality_data[['Vùng', 'Tỷ suất nhập cư', 'Tỷ suất xuất cư', 'Tỷ suất di cư thuần']].copy()
dt5.groupby('Vùng')[['Tỷ suất nhập cư', 'Tỷ suất xuất cư', 'Tỷ suất di cư thuần']].mean()
# Out:
#                    Tỷ suất nhập cư  Tỷ suất xuất cư  Tỷ suất di cư thuần
# Vùng
# An Giang                  2.340714        12.961429           -10.627143
# Bà Rịa - Vũng Tàu         7.325000         5.631429             1.700714
# Bình Dương               45.783571         9.302857            36.481429
# Bình Phước                5.387857         6.318571            -0.930714
# Bình Thuận                1.565000         5.750000            -4.177143
# ...                            ...              ...                  ...
# Ðà Nẵng                  14.412857         5.735000             8.677857
# Ðắk Lắk                   3.526429         6.570714            -3.037143
# Ðắk Nông                 10.020000         6.788571             3.217857
# Ðồng Nai                 13.651429         5.771429             7.865000
# Ðồng Tháp                 2.557857        10.042857            -7.492857
#
# [63 rows x 3 columns]
